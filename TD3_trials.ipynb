# %%
import PIL
import numpy as np
from PIL import Image

import matplotlib.pyplot as pyplot

# %%
img = Image.open("./images/map3.png").convert("L")
# sand = np.asarray(img)/255
sand_copy = img

# %%
sand.shape
plt.imshow(sand)

# %%
x, y = 384, 335

# %%
car = Image.open("./images/car.png").convert("L")
car = car.resize((200, 100))
plt.imshow(car)

# %%
car = Image.open("./images/car.png").convert('RGBA')

# %%
car_rotated = car.rotate(45, expand = 1)
plt.imshow(car_rotated)

# %%
sand_copy.paste(car_rotated, (x, y), car_rotated)
plt.imshow(sand_copy)
